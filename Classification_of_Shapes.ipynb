# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sympy import *
x = symbols('x')

# %%
# Load 1.5 data files
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# ### Equations

# %%
year=[0.0833, 0.1667, 0.25, 0.3333, 0.4167, 0.5, 0.5833, 0.6667, 0.75, 0.8333, 0.9167, 1, 1.0833, 1.1667, 1.25, 1.3333, 1.4167, 1.5]

len(year)
# Out:
# 18

# %% [markdown]
# #### 1.csv

# %%
fname = '1.csv'
df = pd.read_csv(fname)

df
# Out:
#     1952-1953  2014-2015   avg
# 0         0.0       -0.4 -0.20
# 1        -0.1       -0.4 -0.25
# 2         0.0       -0.2 -0.10
# 3         0.2        0.1  0.15
# 4         0.1        0.3  0.20
# 5         0.0        0.2  0.10
# 6         0.1        0.1  0.10
# 7         0.4        0.0  0.20
# 8         0.6        0.2  0.40
# 9         0.6        0.4  0.50
# 10        0.7        0.6  0.65
# 11        0.8        0.7  0.75
# 12        0.8        0.6  0.70
# 13        0.7        0.6  0.65
# 14        0.7        0.6  0.65
# 15        0.8        0.8  0.80
# 16        0.8        1.0  0.90
# 17        0.8        1.2  1.00

# %%
eq1=simplify(((((0.128129)*(x))*(sin((x)/(0.115729))))+((x)+(((0.0719764)-(x))+((0.870872)*(x)))))-(0.351867))

# ((((x)/(sin((0.566917)/(0.352243))))-((((0.868019)-(0.185211))-(sin(0.211902)))*(sin(0.965841))))-((sin(((x)/(0.954814))/((x)-(0.685509))))*(0.144137)))

eq1
# Out:
# 0.128129*x*sin(8.64087653051526*x) + 0.870872*x - 0.2798906

# %%
def func(x):
  # return 1.00074746404839*x-0.144137*np.sin(1.04732440035441*x/(x-0.685509))-0.388634592661657
  return 0.128129*x*np.sin(8.64087653051526*x)+0.870872*x-0.2798906

# %%
y = []

for i in year:
  y.append(func(i))

y
# Out:
# [-0.20031097895442598,
#  -0.1135383679912764,
#  -0.035545418403054196,
#  0.021415308163015623,
#  0.05934372460540982,
#  0.09633918899405847,
#  0.15733177657810327,
#  0.2581031215428877,
#  0.39211673470394226,
#  0.5305756006616189,
#  0.6356292208615638,
#  0.681446577987747,
#  0.6724184373546741,
#  0.6449121069507544,
#  0.6515574199794117,
#  0.7334421864015729,
#  0.8959400986671396,
#  1.1003651306415505]

# %%
plt.figure(figsize=(10,8))
plt.plot(year,df['avg'],'bo',label='avg');
plt.plot(year,y,'ro', label='eq');
# plt.plot(year,df['1952-1953'], 'go', label='1952-1953')
# plt.plot(year,df['2014-2015'], 'co', label='2014-2015')
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 2,4 #best fitness 10.079773
  return 0.128129*x*np.sin(8.046256*x)+0.870872*x-0.228342

new_y = []
for i in year:
  new_y.append(new_func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['1952-1953'], 'bo', label='1952-1953')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,4 #best fitness 13.7775
  return 0.090792*x*np.sin(8.640880*x)+0.870872*x-0.326393

new_y = []
for i in year:
  new_y.append(new_func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['2014-2015'], 'bo', label='2014-2015')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 2.csv

# %%
fname = '2.csv'
df = pd.read_csv(fname)

df
# Out:
#     1969-1970  1979-1980  2004-2005  1987-1988   avg
# 0         0.7        0.0        0.3        0.7  0.43
# 1         1.0        0.1        0.4        0.9  0.60
# 2         1.1        0.2        0.4        1.1  0.70
# 3         1.1        0.3        0.4        1.2  0.75
# 4         0.9        0.2        0.3        1.2  0.65
# 5         0.8        0.0        0.2        1.2  0.55
# 6         0.6        0.0        0.2        1.1  0.48
# 7         0.4        0.2        0.2        0.9  0.43
# 8         0.4        0.3        0.3        1.0  0.50
# 9         0.5        0.5        0.5        1.2  0.68
# 10        0.8        0.5        0.6        1.5  0.85
# 11        0.9        0.6        0.7        1.7  0.98
# 12        0.8        0.6        0.7        1.6  0.93
# 13        0.6        0.5        0.7        1.5  0.83
# 14        0.5        0.3        0.7        1.3  0.70
# 15        0.3        0.4        0.6        1.1  0.60
# 16        0.3        0.5        0.6        0.8  0.55
# ...

# %%
eq2=simplify(((0.592563)+((sin((x)/(0.801401)))*(0.110696)))+(((((x)-(0.17744))*(0.893362))/(((x)+(x))+((x)+(0.0328884))))*(sin(((x)+(x))/(0.266533)))))

eq2
# Out:
# ((0.893362*x - 0.15851815328)*sin(7.50376126033174*x) + (3*x + 0.0328884)*(0.110696*sin(1.24781476439386*x) + 0.592563))/(3*x + 0.0328884)

# %%
def func(x):
  # return 0.110696*np.sin(1.24781476439386*x) + (0.893362*x-0.15851815328) / (3*x+0.0328884)*np.sin(7.50376126033174*x) +0.592563
  return 1.189035*np.sin(0.699276*x)+(-0.920625*x+0.755611)*np.sin(5.417646*x)+0.014571

# %%
y = []

for i in year:
  y.append(func(i))

y
# Out:
# [0.37988915980975757,
#  0.6257030709835923,
#  0.7345808873173137,
#  0.7256376234203913,
#  0.6438240005848711,
#  0.5457284024570309,
#  0.4821784469059563,
#  0.48476662504584367,
#  0.5580800198572681,
#  0.6802008184986506,
#  0.8111284538391174,
#  0.9055588341212478,
#  0.9288734959023935,
#  0.8685847961070302,
#  0.7409329555225316,
#  0.5882911472115026,
#  0.4691766367259319,
#  0.44306971826075636]

# %%
plt.figure(figsize=(10,8))
plt.plot(year,df['avg'],'bo',label='avg');
plt.plot(year,y,'ro', label='eq');
# plt.plot(year,df['1969-1970'], 'mo', label='1969-1970')
# plt.plot(year,df['1979-1980'], 'yo', label='1979-1980')
# plt.plot(year,df['1987-1988'], 'orange', label='1987-1988')
# plt.plot(year,df['2004-2005'], 'go', label='2004-2005')
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  # change 1,2,4 #best fitness 10.5425
  return 0.754583*np.sin(1.650590*x)+(-0.920625*x+0.991321)*np.sin(5.417650*x)+0.014571

new_y = []

for i in year:
  new_y.append(new_func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['1969-1970'], 'bo', label='1969-1970')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  # change 1,2,4,6 #best fitness 10.750963
  return 8.447183*np.sin(0.115486*x)+(-0.920625*x+0.731570)*np.sin(5.417650*x)+-0.483086

new_y = []
for i in year:
  new_y.append(new_func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['1979-1980'], 'bo', label='1979-1980')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  # change 1,2,4,6 #best fitness 7.96481
  return 7.800660*np.sin(0.115838*x)+(-0.920625*x+0.782986)*np.sin(5.417650*x)+-0.296717

new_y = []
for i in year:
  new_y.append(new_func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['2004-2005'], 'bo', label='2004-2005')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  # change 1,2,4 #best fitness 10.6685
  return 1.440270*np.sin(1.468600*x)+(-0.920625*x+0.845974)*np.sin(5.417650*x)+0.014571

new_y = []
for i in year:
  new_y.append(new_func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['1987-1988'], 'bo', label='1987-1988')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 3.csv

# %%
fname = '3.csv'
df = pd.read_csv(fname)

df
# Out:
#     1958-1959  1977-1978   avg
# 0         1.8        0.8  1.30
# 1         1.7        0.7  1.20
# 2         1.3        0.6  0.95
# 3         0.9        0.3  0.60
# 4         0.7        0.2  0.45
# 5         0.6        0.2  0.40
# 6         0.6        0.3  0.45
# 7         0.4        0.4  0.40
# 8         0.4        0.4  0.40
# 9         0.4        0.6  0.50
# 10        0.5        0.7  0.60
# 11        0.6        0.8  0.70
# 12        0.6        0.8  0.70
# 13        0.6        0.7  0.65
# 14        0.5        0.4  0.45
# 15        0.3        0.1  0.20
# 16        0.2       -0.2  0.00
# 17       -0.1       -0.3 -0.20

# %%
eq3=simplify((((sin((0.694731)-(x)))*(((x)-(0.00455926))+((x)-(0.640775))))-((sin((0.795763)+(0.775153)))+(((x)-(0.995554))*((x)+(x)))))*(((0.150117)+((0.0900324)-(0.967598)))-((0.694731)-(x))))

# (((((0.133954)/((x)/(0.978678)))+(sin(((x)-(0.631839))*((x)/(0.312006)))))*((0.133954)/(sin(0.312006))))+(sin((0.199713)/(x))))

eq3
# Out:
# (1.4221796 - x)*(2*x*(x - 0.995554) + (2*x - 0.64533426)*sin(x - 0.694731) + 0.999999992839162)

# %%
def func(x):
  # return np.sin(0.199713/x)+0.436377160972503*np.sin(3.20506656923264*x*(x-0.631839))+0.0572081000921485/x
  return (1.4221796-x)*(2*x*(x-0.995554)+(2*x-0.64533426)*np.sin(x-0.694731)+1.0)

# %%
y = []

for i in year:
  y.append(func(i))

y
# Out:
# [1.5033355166940348,
#  1.1058553138538114,
#  0.808508520374068,
#  0.5999962213145176,
#  0.46851933502777626,
#  0.4019017753516458,
#  0.3868069240913888,
#  0.40963723004253394,
#  0.4563302788863646,
#  0.5127084994335992,
#  0.5646119326548977,
#  0.5978217013576037,
#  0.598618627059747,
#  0.5535772366526376,
#  0.4500503854000171,
#  0.2760069700199713,
#  0.01994184413274346,
#  -0.32770887774262275]

# %%
plt.figure(figsize=(10,8))
plt.plot(year,df['avg'],'bo',label='avg');
plt.plot(year,y,'ro', label='eq');
# plt.plot(year,df['1958-1959'], 'go', label='1958-1959')
# plt.plot(year,df['1977-1978'], 'co', label='1977-1978')
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  # change 3 #best fitness 11.8577
  return (1.422180-x)*(2*x*(x-0.995554)+(2*x-1.339720)*np.sin(x-0.694731)+1.0)

new_y = []
for i in year:
  new_y.append(new_func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['1958-1959'], 'bo', label='1958-1959')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 3 #best fitness 10.795051
  return (1.422180-x)*(2*x*(x-0.995554)+(2*x--0.114362)*np.sin(x-0.694731)+1.0)

new_y = []
for i in year:
  new_y.append(new_func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['1977-1978'], 'bo', label='1977-1978')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 4.csv

# %%
fname = '4.csv'
df = pd.read_csv(fname)

df
# Out:
#     2006-2007  1963-1964  1994-1995  2002-2003  2009-2010  1957-1958  \
# 0        -0.8       -0.4        0.1       -0.3       -0.8        0.1
# 1        -0.8       -0.4        0.1       -0.1       -0.7        0.4
# 2        -0.7       -0.2        0.2        0.0       -0.5        0.7
# 3        -0.5        0.2        0.3        0.1       -0.2        0.9
# 4        -0.3        0.3        0.4        0.2        0.1        1.1
# 5         0.0        0.3        0.4        0.4        0.4        1.3
# 6         0.0        0.5        0.4        0.7        0.5        1.3
# 7         0.1        0.9        0.4        0.8        0.5        1.3
# 8         0.3        1.1        0.6        0.9        0.7        1.4
# 9         0.5        1.2        0.7        1.0        1.0        1.5
# 10        0.7        1.3        1.0        1.2        1.3        1.7
# 11        0.9        1.4        1.1        1.3        1.6        1.8
# 12        0.9        1.3        1.0        1.1        1.5        1.7
# ...

# %%
eq4=simplify((sin(((x)-((0.13708)-(x)))*((x)*(0.99257))))-((0.382106)-((0.851071)*(((x)*(0.992231))*(0.992231)))))

# ((sin(((0.890162)+((x)*(x)))*(x)))+(sin((((x)*(x))-((x)*(0.430875)))-(((0.303897)*(0.552399))/((x)+(0.375517))))))

eq4
# Out:
# 0.837898427201584*x + sin(x*(1.98514*x - 0.1360614956)) - 0.382106

# %%
def func(x):
  # return np.sin(x*(x**2+0.890162)) - np.sin(x*(0.430875-x) + 0.167872398903/(x+0.375517)) 
  return 0.660694*x+x*np.sin(3.211015*x-1.065241)-0.192678

# %%
y = []

for i in year:
  y.append(func(i))

y
# Out:
# [-0.19726800318021756,
#  -0.16680765524088348,
#  -0.09237535192104275,
#  0.029194570119944918,
#  0.19489979756727951,
#  0.3948512763782217,
#  0.614273136542772,
#  0.8344014854182079,
#  1.033470743472665,
#  1.1905216698374406,
#  1.286680728255699,
#  1.3072204442993196,
#  1.2441315529271846,
#  1.0966749636858861,
#  0.8730241894185639,
#  0.5891024663983834,
#  0.26792377453891947,
#  -0.060555593924924794]

# %%
plt.figure(figsize=(10,8))
plt.plot(year,df['avg'],'bo',label='avg');
plt.plot(year,y,'ro', label='eq');
# plt.plot(year,df['2002-2003'], 'go', label='2002-2003')
# plt.plot(year,df['2006-2007'], 'co', label='2006-2007')
# plt.plot(year,df['2009-2010'], 'mo', label='2009-2010')
# plt.plot(year,df['1957-1958'], 'yo', label='1957-1958')
# plt.plot(year,df['1963-1964'], 'orange', label='1963-1964')
# plt.plot(year,df['1982-1983'], 'olive', label='1982-1983')
# plt.plot(year,df['1994-1995'], 'pink', label='1994-1995')
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 3,4 #best fitness 11.641994
  return 0.660694*x+x*np.sin(3.211010*x-1.164224)-0.756267

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['2006-2007'], 'bo', label='2006-2007')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3 #best fitness 18.105898
  return 0.590984*x+x*np.sin(3.211015*x-0.908812)-0.192678

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1963-1964'], 'bo', label='1963-1964')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3,4 #best fitness 15.751081
  return -0.370771*x+x*np.sin(3.211010*x-1.542475)--0.396837

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1994-1995'], 'bo', label='1994-1995')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3 #best fitness 6.638339
  return 0.594481*x+x*np.sin(3.211010*x-0.952424)-0.192678

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['2002-2003'], 'bo', label='2002-2003')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,2,4 #best fitness 23.579988
  return 1.109158*x+x*np.sin(3.366371*x-1.065241)-0.645433

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['2009-2010'], 'bo', label='2009-2010')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3,4 #best fitness 16.024298
  return 1.225919*x+x*np.sin(3.211010*x-0.332064)--0.114485

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1957-1958'], 'bo', label='1957-1958')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3,4 #best fitness 15.245098
  return 1.028580*x+x*np.sin(3.211010*x-1.417940)-0.039754

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1982-1983'], 'bo', label='1982-1983')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 5.csv

# %%
fname = '5.csv'
df = pd.read_csv(fname)

df
# Out:
#     2018-2019  1951-1952  1976-1977  1986-1987   avg
# 0        -1.0       -0.6       -1.7       -0.5 -0.95
# 1        -0.9       -0.8       -1.6       -0.5 -0.95
# 2        -0.9       -0.8       -1.2       -0.3 -0.80
# 3        -0.7       -0.5       -0.7       -0.2 -0.53
# 4        -0.5       -0.2       -0.5       -0.1 -0.33
# 5        -0.2        0.2       -0.3        0.0 -0.08
# 6         0.0        0.4        0.0        0.2  0.15
# 7         0.1        0.6        0.2        0.4  0.33
# 8         0.2        0.7        0.4        0.7  0.50
# 9         0.5        0.9        0.6        0.9  0.73
# 10        0.8        1.0        0.8        1.1  0.93
# 11        0.9        1.2        0.9        1.2  1.05
# 12        0.8        1.0        0.8        1.2  0.95
# 13        0.8        0.8        0.7        1.2  0.88
# 14        0.7        0.5        0.6        1.1  0.73
# 15        0.7        0.4        0.3        0.9  0.58
# 16        0.7        0.3        0.2        1.0  0.55
# ...

# %%
eq5=simplify(sin(((sin((x)-(0.516948)))+(sin((x)-(0.51781))))-(sin(((0.564075)*(0.569863))-((x)*(x))))))

# (sin(((((x)*(0.906024))+(x))-(((x)/(x))-((x)-(0.580189))))+((((x)-(0.839746))*((0.33426)-(x)))*(sin((x)/(0.228209))))))

eq5

# %%
def func(x):
  # return -np.sin(-2.906024*x+(x-0.839746)*(x-0.33426)*np.sin(4.38194812649808*x)+1.580189)
  return np.sin(2.892047*x+4.724232)

# %%
y = []

for i in year:
  y.append(func(i))

y
# Out:
# [-0.9682282642673721,
#  -0.8804683095470323,
#  -0.7419281352092701,
#  -0.5605369460710691,
#  -0.34649994985954435,
#  -0.11268992522752012,
#  0.12762865114236596,
#  0.3608456052073292,
#  0.5729346224474388,
#  0.7519330628229108,
#  0.8876358700896477,
#  0.9718815010031094,
#  0.9999948643728814,
#  0.9702822967501507,
#  0.8845307943691405,
#  0.7476920769841254,
#  0.5674313275091493,
#  0.35458992742898254]

# %%
plt.figure(figsize=(10,8))
plt.plot(year,df['avg'],'bo',label='avg');
plt.plot(year,y,'ro', label='eq');
# plt.plot(year,df['2018-2019'], 'go', label='2018-2019')
# plt.plot(year,df['1951-1952'], 'co', label='1951-1952')
# plt.plot(year,df['1976-1977'], 'mo', label='1976-1977')
# plt.plot(year,df['1986-1987'], 'yo', label='1986-1987')
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,2 #best fitness 11.6058
  return np.sin(2.955150*x+4.485220)
  
new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['2018-2019'], 'bo', label='2018-2019')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,2 #best fitness 13.713657
  return np.sin(2.980902*x+4.894319)

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1951-1952'], 'bo', label='1951-1952')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,2 #best fitness 26.215099
  return np.sin(3.486610*x+4.227690)

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1976-1977'], 'bo', label='1976-1977')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  # change 1,2 #best fitness 16.749201
  return np.sin(1.958630*x+-0.820861)

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1986-1987'], 'bo', label='1986-1987')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 6.csv

# %%
fname = '6.csv'
df = pd.read_csv(fname)

df
# Out:
#     1965-1966  1972-1973  1997-1998  2015-2016   avg
# 0        -0.8       -1.0       -0.5        0.7 -0.40
# 1        -0.8       -0.9       -0.5        0.6 -0.40
# 2        -0.8       -0.7       -0.4        0.6 -0.33
# 3        -0.6       -0.4       -0.1        0.6 -0.13
# 4        -0.3        0.1        0.3        0.8  0.23
# 5        -0.1        0.4        0.8        1.0  0.53
# 6         0.2        0.7        1.2        1.2  0.83
# 7         0.5        0.9        1.6        1.5  1.13
# 8         0.8        1.1        1.9        1.9  1.43
# 9         1.2        1.4        2.1        2.2  1.73
# 10        1.5        1.6        2.3        2.4  1.95
# 11        1.9        1.8        2.4        2.6  2.18
# 12        2.0        2.1        2.4        2.6  2.28
# 13        2.0        2.1        2.2        2.5  2.20
# 14        1.7        1.8        1.9        2.1  1.88
# 15        1.4        1.2        1.4        1.6  1.40
# 16        1.2        0.5        1.0        0.9  0.90
# ...

# %%
eq6=simplify(((sin(((x)*(x))/((0.868239)*(0.767811))))/(sin(sin((0.31453)/(0.516318)))))+(((((0.803712)-(x))*(0.195538))*(sin((x)/(0.0665014))))-((0.681651)-(x))))

eq6
# Out:
# x + (0.157156237056 - 0.195538*x)*sin(15.0372774107011*x) + 1.84679692579575*sin(1.50005222845323*x**2) - 0.681651

# %%
def func(x):
  return x+(-0.497150-3.264897*x)*np.sin(2.908535*x)+5.213310*x*np.sin(2.648657*x)-0.441066
  # x+(0.157156237056-0.195538*x)*np.sin(15.0372774107011*x)+1.84679692579575*np.sin(1.50005222845323*x**2)-0.681651

# %%
y = []

for i in year:
  y.append(func(i))

y
# Out:
# [-0.44725183997119566,
#  -0.38837374255941626,
#  -0.2627881016565649,
#  -0.07264097568513611,
#  0.17597871250997804,
#  0.4716605562472617,
#  0.7995422348764227,
#  1.1409053492405679,
#  1.4724075553708997,
#  1.7695375443831411,
#  2.0064896201032174,
#  2.1570874442237553,
#  2.198355796052792,
#  2.111042970037153,
#  1.882489441096104,
#  1.5078555068795365,
#  0.9911996825987013,
#  0.34919770310503234]

# %%
plt.figure(figsize=(10,8))
plt.plot(year,df['avg'],'bo',label='avg');
plt.plot(year,y,'ro', label='eq');
# plt.plot(year,df['1965-1966'], 'go', label='1965-1966')
# plt.plot(year,df['1972-1973'], 'co', label='1972-1973')
# plt.plot(year,df['1997-1998'], 'mo', label='1997-1998')
# plt.plot(year,df['2015-2016'], 'yo', label='2015-2016')
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3 #best fitness 11.954185
  return x+(-1.145090-3.264897*x)*np.sin(2.849602*x)+5.213310*x*np.sin(2.648657*x)-0.441066

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1965-1966'], 'bo', label='1965-1966')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3,6 #best fitness 14.265
  return x+(-0.290019-3.264900*x)*np.sin(2.981270*x)+5.213310*x*np.sin(2.648660*x)-0.924186

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1972-1973'], 'bo', label='1972-1973')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3,6 #best fitness 15.091798
  return x+(-0.220951-3.264897*x)*np.sin(2.973420*x)+5.213310*x*np.sin(2.648657*x)-0.488703

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1997-1998'], 'bo', label='1997-1998')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 1,3,5,6 #best fitness 10.043792
  return x+(-11.884934-3.264900*x)*np.sin(0.300947*x)+5.213310*x*np.sin(1.588590*x)--0.750941

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['2015-2016'], 'bo', label='2015-2016')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 7.csv

# %%
fname = '7.csv'
df = pd.read_csv(fname)

df
# Out:
#     1968-1969  1991-1992   avg
# 0        -0.7        0.3 -0.20
# 1        -0.6        0.2 -0.20
# 2        -0.4        0.3 -0.05
# 3         0.0        0.5  0.25
# 4         0.3        0.6  0.45
# 5         0.6        0.7  0.65
# 6         0.5        0.6  0.55
# 7         0.4        0.6  0.50
# 8         0.5        0.8  0.65
# 9         0.7        1.2  0.95
# 10        1.0        1.5  1.25
# 11        1.1        1.7  1.40
# 12        1.1        1.6  1.35
# 13        0.9        1.5  1.20
# 14        0.8        1.3  1.05
# 15        0.6        1.1  0.85
# 16        0.4        0.7  0.55
# 17        0.4        0.4  0.40

# %%
eq7=simplify(((((sin(0.766124))/((x)-(0.53707)))*((0.77372)-((0.498084)/(0.498012))))*((0.53707)*(((0.268375)-(x))*((x)-(0.844566)))))+((sin(((x)-(0.53707))+((x)*(x))))+(0.257176)))

eq7

# %%
def func(x):
  # return 0.0843150967836997*(x-0.844566)*(x-0.268375) / (x-0.53707) + np.sin(x**2+x-0.53707) +0.257176
  return 1.270450*np.sin(0.869869*x)+(0.873001*x-0.504249)*np.sin(7.622553*x)

# %%
y = []

for i in year:
  y.append(func(i))

y
# Out:
# [-0.16398197319776014,
#  -0.15910626141785106,
#  0.003993733818951184,
#  0.24259864265736458,
#  0.4553643758779667,
#  0.5773594569713068,
#  0.6125164565371147,
#  0.6236457098853759,
#  0.6905434870544114,
#  0.8576697254652901,
#  1.1007733757487803,
#  1.3298553348261994,
#  1.4337187187722182,
#  1.3398112874482502,
#  1.06425035029922,
#  0.7205995064268884,
#  0.4799711917634587,
#  0.4966199356649629]

# %%
plt.figure(figsize=(10,8))
plt.plot(year,df['avg'],'bo',label='avg');
plt.plot(year,y,'ro', label='eq');
# plt.plot(year,df['1968-1969'], 'co', label='1968-1969')
# plt.plot(year,df['1991-1992'], 'mo', label='1991-1992')
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 2,4 #best fitness 15.224091
  return 1.270450*np.sin(0.607653*x)+(0.873001*x-0.671472)*np.sin(7.622553*x)

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1968-1969'], 'bo', label='1968-1969')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %%
def new_func(x):
  #change 2,4 #best fitness 15.917866
  return 1.270450*np.sin(1.187490*x)+(0.873001*x-0.368266)*np.sin(7.622550*x)

new_y = []
for i in year:
  new_y.append(new_func(i))  

plt.figure(figsize=(10,8))
plt.plot(year,df['1991-1992'], 'bo', label='1991-1992')
plt.plot(year,new_y,'r*', label='new_eq');
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 8.csv

# %%
fname = '8.csv'
df = pd.read_csv(fname)

df
# Out:
#     1953-1954
# 0         0.1
# 1         0.0
# 2         0.1
# 3         0.4
# 4         0.6
# 5         0.6
# 6         0.7
# 7         0.8
# 8         0.8
# 9         0.7
# 10        0.7
# 11        0.8
# 12        0.8
# 13        0.8
# 14        0.8
# 15        0.8
# 16        0.5
# 17        0.0

# %%
eq8=simplify(sin(sin(((x)*((x)+(0.94851)))*(((x)+(0.750041))-((x)*(x))))))

eq8
# Out:
# sin(sin(x*(x + 0.94851)*(-x**2 + x + 0.750041)))

# %%
def func(x):
  return -0.513958*x-(4.298025*x-0.378910)*np.sin(x-1.612762)+(x-2.151642)*x*np.sin(2.249024*x)
  # 1.263607*x-(2.080498*x-0.673312)*np.sin(x-0.356829)+(x-0.540460)*x*np.sin(1.853157*x)
  # 0.188944*x-(1.093899*x-1.958744)*np.sin(x-6.378759)+(x-0.575392)*x*np.sin(2.445303*x)

# %%
y = []

for i in year:
  y.append(func(i))

plt.figure(figsize=(10,8))
plt.plot(year,df['1953-1954'],'bo',label='1953-1954');
plt.plot(year,y,'ro', label='eq');
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# ### Classification of Shapes

# %%
year=[0.0833, 0.1667, 0.25, 0.3333, 0.4167, 0.5, 0.5833, 0.6667, 0.75, 0.8333, 0.9167, 1, 1.0833, 1.1667, 1.25, 1.3333, 1.4167, 1.5]

len(year)
# Out:
# 18

# %% [markdown]
# #### 1.csv

# %%
fname = '1.csv'
df = pd.read_csv(fname)

df
# Out:
#     1952-1953  2014-2015   avg
# 0         0.0       -0.4 -0.20
# 1        -0.1       -0.4 -0.25
# 2         0.0       -0.2 -0.10
# 3         0.2        0.1  0.15
# 4         0.1        0.3  0.20
# 5         0.0        0.2  0.10
# 6         0.1        0.1  0.10
# 7         0.4        0.0  0.20
# 8         0.6        0.2  0.40
# 9         0.6        0.4  0.50
# 10        0.7        0.6  0.65
# 11        0.8        0.7  0.75
# 12        0.8        0.6  0.70
# 13        0.7        0.6  0.65
# 14        0.7        0.6  0.65
# 15        0.8        0.8  0.80
# 16        0.8        1.0  0.90
# 17        0.8        1.2  1.00

# %%
plt.figure(figsize=(8,6))
plt.plot(year,df['1952-1953'], 'bo-', label='1952-1953 WE')
plt.plot(year,df['2014-2015'], 'ro-', label='2014-2015 WE')
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 2.csv

# %%
fname = '2.csv'
df = pd.read_csv(fname)

df
# Out:
#     1969-1970  1979-1980  2004-2005  1987-1988   avg
# 0         0.7        0.0        0.3        0.7  0.43
# 1         1.0        0.1        0.4        0.9  0.60
# 2         1.1        0.2        0.4        1.1  0.70
# 3         1.1        0.3        0.4        1.2  0.75
# 4         0.9        0.2        0.3        1.2  0.65
# 5         0.8        0.0        0.2        1.2  0.55
# 6         0.6        0.0        0.2        1.1  0.48
# 7         0.4        0.2        0.2        0.9  0.43
# 8         0.4        0.3        0.3        1.0  0.50
# 9         0.5        0.5        0.5        1.2  0.68
# 10        0.8        0.5        0.6        1.5  0.85
# 11        0.9        0.6        0.7        1.7  0.98
# 12        0.8        0.6        0.7        1.6  0.93
# 13        0.6        0.5        0.7        1.5  0.83
# 14        0.5        0.3        0.7        1.3  0.70
# 15        0.3        0.4        0.6        1.1  0.60
# 16        0.3        0.5        0.6        0.8  0.55
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(year,df['1969-1970'], 'ro-', label='1969-1970 WE')
plt.plot(year,df['1979-1980'], 'go-', label='1979-1980 WE')
plt.plot(year,df['1987-1988'], 'bo-', label='1987-1988 SE')
plt.plot(year,df['2004-2005'], 'ko-', label='2004-2005 WE')
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 3.csv

# %%
fname = '3.csv'
df = pd.read_csv(fname)

df
# Out:
#     1958-1959  1977-1978   avg
# 0         1.8        0.8  1.30
# 1         1.7        0.7  1.20
# 2         1.3        0.6  0.95
# 3         0.9        0.3  0.60
# 4         0.7        0.2  0.45
# 5         0.6        0.2  0.40
# 6         0.6        0.3  0.45
# 7         0.4        0.4  0.40
# 8         0.4        0.4  0.40
# 9         0.4        0.6  0.50
# 10        0.5        0.7  0.60
# 11        0.6        0.8  0.70
# 12        0.6        0.8  0.70
# 13        0.6        0.7  0.65
# 14        0.5        0.4  0.45
# 15        0.3        0.1  0.20
# 16        0.2       -0.2  0.00
# 17       -0.1       -0.3 -0.20

# %%
plt.figure(figsize=(8,6))
plt.plot(year,df['1958-1959'], 'bo-', label='1958-1959 WE')
plt.plot(year,df['1977-1978'], 'ro-', label='1977-1978 WE')
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 4.csv

# %%
fname = '4.csv'
df = pd.read_csv(fname)

df
# Out:
#     2006-2007  1963-1964  1994-1995  2002-2003  2009-2010  1957-1958  \
# 0        -0.8       -0.4        0.1       -0.3       -0.8        0.1
# 1        -0.8       -0.4        0.1       -0.1       -0.7        0.4
# 2        -0.7       -0.2        0.2        0.0       -0.5        0.7
# 3        -0.5        0.2        0.3        0.1       -0.2        0.9
# 4        -0.3        0.3        0.4        0.2        0.1        1.1
# 5         0.0        0.3        0.4        0.4        0.4        1.3
# 6         0.0        0.5        0.4        0.7        0.5        1.3
# 7         0.1        0.9        0.4        0.8        0.5        1.3
# 8         0.3        1.1        0.6        0.9        0.7        1.4
# 9         0.5        1.2        0.7        1.0        1.0        1.5
# 10        0.7        1.3        1.0        1.2        1.3        1.7
# 11        0.9        1.4        1.1        1.3        1.6        1.8
# 12        0.9        1.3        1.0        1.1        1.5        1.7
# ...

# %%
plt.figure(figsize=(10,8))
plt.plot(year,df['2002-2003'], 'go-', label='2002-2003 ME')
plt.plot(year,df['2006-2007'], 'co-', label='2006-2007 WE')
plt.plot(year,df['2009-2010'], 'mo-', label='2009-2010 ME')
plt.plot(year,df['1957-1958'], 'yo-', label='1957-1958 SE')
plt.plot(year,df['1963-1964'], 'bo-', label='1963-1964 ME')
plt.plot(year,df['1982-1983'], 'ro-', label='1982-1983 VSE')
plt.plot(year,df['1994-1995'], 'ko-', label='1994-1995 ME')
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 5.csv

# %%
fname = '5.csv'
df = pd.read_csv(fname)

df
# Out:
#     2018-2019  1951-1952  1976-1977  1986-1987   avg
# 0        -1.0       -0.6       -1.7       -0.5 -0.95
# 1        -0.9       -0.8       -1.6       -0.5 -0.95
# 2        -0.9       -0.8       -1.2       -0.3 -0.80
# 3        -0.7       -0.5       -0.7       -0.2 -0.53
# 4        -0.5       -0.2       -0.5       -0.1 -0.33
# 5        -0.2        0.2       -0.3        0.0 -0.08
# 6         0.0        0.4        0.0        0.2  0.15
# 7         0.1        0.6        0.2        0.4  0.33
# 8         0.2        0.7        0.4        0.7  0.50
# 9         0.5        0.9        0.6        0.9  0.73
# 10        0.8        1.0        0.8        1.1  0.93
# 11        0.9        1.2        0.9        1.2  1.05
# 12        0.8        1.0        0.8        1.2  0.95
# 13        0.8        0.8        0.7        1.2  0.88
# 14        0.7        0.5        0.6        1.1  0.73
# 15        0.7        0.4        0.3        0.9  0.58
# 16        0.7        0.3        0.2        1.0  0.55
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(year,df['2018-2019'], 'ko-', label='2018-2019 WE')
plt.plot(year,df['1951-1952'], 'co-', label='1951-1952 ME')
plt.plot(year,df['1976-1977'], 'mo-', label='1976-1977 WE')
plt.plot(year,df['1986-1987'], 'ro-', label='1986-1987 ME')
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 6.csv

# %%
fname = '6.csv'
df = pd.read_csv(fname)

df
# Out:
#     1965-1966  1972-1973  1997-1998  2015-2016   avg
# 0        -0.8       -1.0       -0.5        0.7 -0.40
# 1        -0.8       -0.9       -0.5        0.6 -0.40
# 2        -0.8       -0.7       -0.4        0.6 -0.33
# 3        -0.6       -0.4       -0.1        0.6 -0.13
# 4        -0.3        0.1        0.3        0.8  0.23
# 5        -0.1        0.4        0.8        1.0  0.53
# 6         0.2        0.7        1.2        1.2  0.83
# 7         0.5        0.9        1.6        1.5  1.13
# 8         0.8        1.1        1.9        1.9  1.43
# 9         1.2        1.4        2.1        2.2  1.73
# 10        1.5        1.6        2.3        2.4  1.95
# 11        1.9        1.8        2.4        2.6  2.18
# 12        2.0        2.1        2.4        2.6  2.28
# 13        2.0        2.1        2.2        2.5  2.20
# 14        1.7        1.8        1.9        2.1  1.88
# 15        1.4        1.2        1.4        1.6  1.40
# 16        1.2        0.5        1.0        0.9  0.90
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(year,df['1965-1966'], 'ko-', label='1965-1966 SE')
plt.plot(year,df['1972-1973'], 'co-', label='1972-1973 SE')
plt.plot(year,df['1997-1998'], 'mo-', label='1997-1998 VSE')
plt.plot(year,df['2015-2016'], 'ro-', label='2015-2016 VSE')
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 7.csv

# %%
fname = '7.csv'
df = pd.read_csv(fname)

df
# Out:
#     1968-1969  1991-1992   avg
# 0        -0.7        0.3 -0.20
# 1        -0.6        0.2 -0.20
# 2        -0.4        0.3 -0.05
# 3         0.0        0.5  0.25
# 4         0.3        0.6  0.45
# 5         0.6        0.7  0.65
# 6         0.5        0.6  0.55
# 7         0.4        0.6  0.50
# 8         0.5        0.8  0.65
# 9         0.7        1.2  0.95
# 10        1.0        1.5  1.25
# 11        1.1        1.7  1.40
# 12        1.1        1.6  1.35
# 13        0.9        1.5  1.20
# 14        0.8        1.3  1.05
# 15        0.6        1.1  0.85
# 16        0.4        0.7  0.55
# 17        0.4        0.4  0.40

# %%
plt.figure(figsize=(8,6))
plt.plot(year,df['1968-1969'], 'bo-', label='1968-1969 ME')
plt.plot(year,df['1991-1992'], 'ro-', label='1991-1992 SE')
plt.grid()
plt.legend()
plt.show();

# %% [markdown]
# #### 8.csv

# %%
fname = '8.csv'
df = pd.read_csv(fname)

df
# Out:
#     1953-1954
# 0         0.1
# 1         0.0
# 2         0.1
# 3         0.4
# 4         0.6
# 5         0.6
# 6         0.7
# 7         0.8
# 8         0.8
# 9         0.7
# 10        0.7
# 11        0.8
# 12        0.8
# 13        0.8
# 14        0.8
# 15        0.8
# 16        0.5
# 17        0.0

# %%
plt.figure(figsize=(8,6))
plt.plot(year,df['1953-1954'], 'bo-', label='1953-1954 WE')
plt.grid()
plt.legend()
plt.show();
